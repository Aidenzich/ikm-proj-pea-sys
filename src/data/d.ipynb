# %%
import pandas as pd

# %%
pd.read_csv("./revise_length_10.csv")
# Out:
#       year                           name  \
# 0      103                   國家生技研究園區開發計畫
# 1      103  創新轉譯農學研究：從系統生物學到農業生技產品關鍵技術之開發
# 2      103                科技會報科技政策發展研究與諮詢
# 3      103              臺灣經典電影數位修復及加值利用計畫
# 4      103                     數位媒體發展中心計畫
# ...    ...                            ...
# 1608   110             110年度「再生能源開發與推廣計畫」
# 1609   110              110年度「節約能源技術研發計畫」
# 1610   110         110年度｢能源效率管理與節能技術推廣輔導」
# 1611   110    儲能系統與智慧家庭能源管理系統標準檢測驗證能量建置計畫
# 1612   110                  商業服務業節能低碳推動計畫
#
#                                                   label  year_start  year_end  \
# 0     生技醫藥核心設施/生醫技術與新藥研發/生醫產業法規與檢驗/新穎與罕病研究/精準治療技術/重大...         103       106
# 1                  農業政策與技術研發/科技計畫管理與國際合作/氣候變遷與糧食安全/食品安全         103       107
# 2     5G/雲端技術及服務/資安、數位人才培育/智慧電子、機械/AI技術及應用/晶片半導體/智慧醫...         103       104
# 3     影音、博物館數位內容/文化資產保護及加值應用/文化內容科技/科普教育/數位人文人才培育/體感...         103       107
# ...
