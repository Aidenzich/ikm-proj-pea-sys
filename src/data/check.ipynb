# %%
import pandas as pd

df = pd.read_excel("./0324_combine.xlsx")

df
# df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#       Unnamed: 0          系統編號                            計畫完整中文名稱   年度  \
# 0              0   MP1024-0018                   國家生技研究園區開發計畫(1/3)  103
# 1              1   MP1024-0019  創新轉譯農學研究：從系統生物學到農業生技產品關鍵技術之開發(1/4)  103
# 2              2   MP1023-0035                科技會報科技政策發展研究與諮詢(1/1)  103
# 3              3   MP1022-0046              臺灣經典電影數位修復及加值利用計畫(2/4)  103
# 4              4   MP1022-0110                     數位媒體發展中心計畫(2/4)  103
# ...          ...           ...                                 ...  ...
# 3147        3147  MP10902-0069             110年度「再生能源開發與推廣計畫」(1/1)  110
# 3148        3148  MP10902-0163              110年度「節約能源技術研發計畫」(3/3)  110
# 3149        3149  MP10902-0169         110年度｢能源效率管理與節能技術推廣輔導」(1/1)  110
# 3150        3150  MP10902-0288    儲能系統與智慧家庭能源管理系統標準檢測驗證能量建置計畫(1/4)  110
# 3151        3151  MP10904-0006                  商業服務業節能低碳推動計畫(1/1)  110
#
#                    部會     主題重新分類  主題1  次主題1  主題2 次主題2  ... 政策編號5-名稱 政策編號5-措施  \
# 0          0210:中央研究院  生技醫藥與精準醫療  NaN   NaN  NaN  NaN  ...      NaN      NaN
# 1          0210:中央研究院       農業生技  NaN   NaN  NaN  NaN  ...      NaN      NaN
# 2     0302:行政院科技會報辦公室    政策規劃與推動  NaN   NaN  NaN  NaN  ...      NaN      NaN
# 3            0307:文化部       數位內容  NaN   NaN  NaN  NaN  ...      NaN      NaN
# 4            0307:文化部       數位內容  NaN   NaN  NaN  NaN  ...      NaN      NaN
# ...               ...        ...  ...   ...  ...  ...  ...      ...      ...
# 3147     8001:石油及能源基金        NaN   電池  燃料電池  NaN  NaN  ...      NaN      NaN
# 3148     8001:石油及能源基金        NaN  NaN   NaN  NaN  NaN  ...      NaN      NaN
# 3149     8001:石油及能源基金        NaN  NaN   NaN  NaN  NaN  ...      NaN      NaN
# 3150     8001:石油及能源基金        NaN   電池   鋰電池  NaN  NaN  ...      NaN      NaN
# 3151     8001:石油及能源基金        NaN  NaN   NaN  NaN  NaN  ...      NaN      NaN
#
#                                                  政策其他理由  \
# 0                                                   NaN
# 1     中研院首長政策: (1) 擬定學術研究方向，帶動國家追求學術卓越。(2) 培育各領域尖端研究...
# 2     依據「行政院科技會報設置要點」，職掌任務係統籌規劃國家科技發展政策、國家科技資源分配、重大科...
# 3                                                   NaN
# 4     一、依據100年4月28日總統府財經會報第19次會議及100年8月25日總統府財經會報第23...
# ...                                                 ...
# 3147                                                NaN
# 3148                                                NaN
# 3149                                                NaN
# 3150  5.行政院106年「綠能科技產業創新推動方案」，推動包含節能、創能、儲能及智慧系統整合之能源...
# 3151                                                NaN
#
#                                          本計畫在施政項目之定位及功能  \
# 0     「國家生技研究園區」主要以研發新藥、新試劑及新疫苗為主，係能提供市場新藥之任務型導向研究，期...
# 1     本院長期致力於發展創新科學，本計畫除將已有相當基礎之主題計畫篩選出具應用潛力作為產業革新之儲...
# 2     1.國家科技發展政策之審議_x000D_\n2.國家科技資源之分配_x000D_\n3.重大...
# 3     1.為配合全國科學技術會議(國家科學技術發展計畫)國家科技發展重要措施之促進科技與人文社會互...
# 4     本計畫主要希望透過跨部會工作的整合與協調，落實推動數位匯流發展方案，推動數位匯流產業發展；並...
# ...                                                 ...
# 3147  一、為推動有關能源科技計畫之整體發展，在本項「再生能源開發與推廣」計畫辦理研究發展外、亦進行...
# 3148  依據能源政策發展綱領，於需求面強化節能，透過節能技術研發與示範應用，並提供適當誘因引導節能，...
# 3149  　　我國能源政策旨在建構安全穩定、效率運用、潔淨環境之能源供需系統，營造有助節能減碳之發展環...
# 3150  1.\t建置標準、檢測技術和驗證平台，協助產業產品研發和商品過程所需要的依據、評估技術，並培...
# 3151  在推動商業服務業節能減碳上，透過「能耗評估與檢測」及「落實節能」等解決方案，提供業者從規劃至...
#
#                                                  計畫重點描述  \
# 0      「國家生技研究園區」係以R&D為主的新一代國家型研究園區，主要以新藥研發為主。園區將基礎研...
# 1     本計畫將系統生物學帶入轉譯農學研究，著重於農業生技產品關鍵技術之開發；並針對物種進行功能性探...
# 2     1.辦理國家科技政策形成重要策略會議_x000D_\n2.辦理重大科技發展計畫之審議及管考_...
# 3     本計畫期程為102-105年，以每年修復8部影片(含劇情片及新聞紀錄片)為原則，委託財團法人...
# 4     1、導入異業結盟及合作契機，開發影視多元、多樣、多用界面。_x000D_\n2、搭建跨部會合...
# ...                                                 ...
# 3147  本項109年度「再生能源開發與推廣」計畫於110 年度進行下列9項分項計畫，相關之經費來源為...
# 3148  一、本計畫係配合綠能科技重點政策，於政府推動創能、節能、儲能及系統整合四大主軸中之「節能」與...
# 3149  1.能源查核與輔導：由自願性規範切入，視相關利害關係人因應能力，逐步演化制訂並執行強制性產品...
# 3150          本計畫係配合綠能政策目標時程，務須於113年底前完成大型儲能系統與電力智慧調...
# 3151  環保署現階段規劃住商部門2025年溫室氣體排放管制目標為較基準年 (2005年) 降低24%...
#
#                                                    最終效益  \
# 0     本園區引進產業將以生技產業為主，包括醫藥等相關研究非短期內就能夠有所成果，見諸成效，往往必須...
# 1     功能性體學資料平臺之建立將能縮短學術研究期程進行有效開發，除了增進國內外基因體學資訊交流，更...
# 2     1.辦理每三個月召開1次之科技會報。_x000D_\n2.辦理104年度政府科技資源之政策審...
# 3     1.舉辦研討會(國際)和工作坊，可帶動對數位修復之知識、技術交流與傳授以及實際執行問題之探討...
# 4     1.促成跨業媒合，打造數位媒體典範案例。_x000D_\n2.擴大一源多用乘數效應，發展數位...
# ...                                                 ...
# 3147  一、整合研究國內外推動再生能源政策，分析法規、推動機制與分散式能源併聯技術規範，探討國際再生...
# 3148  1.提升能源使用效率，協助推動節能工作_x000D_\n(1)帶動國內高效率冰水機產業能效提...
# 3149  　　本計畫旨在推動節能獎勵補助、能源查核與節能輔導、節能教育與宣導、節能政策規劃、能源效率強...
# 3150  1.\t逐步補足現有電動車輛暨電業儲能系統安全檢測缺口，保障電力系統與民眾安全。鑒於現有電動...
# 3151  一、協助商業服務業用戶及商業公協會會員等，發掘節能潛力至少為2,510萬度/年及減碳潛力13...
#
#                                            主要績效指標(~107)  \
# 0     為達開發目標及經濟效益，茲針對園區需求訂定績效指標及基準，評量結果說明如下：_x000D_\...
# 1     除了國內外期刊論文發表、關鍵技術(專利及Know-how)突破、前瞻技術應用、作物花卉新品種...
# 2                                  落實推動相關工作，達成前述計畫之預期效益
# 3     學術成就（科技基礎研究）、技術創新（科技整合創新）、經濟效益（產業經濟發展）、社會影響（民生...
# 4     1.辦理行政院數位匯流專案小組委員會議2場次以上。 _x000D_\n2.完成盤點影視產業公...
# ...                                                 ...
# 3147                                                NaN
# 3148                                                NaN
# 3149                                                NaN
# 3150                                                NaN
# 3151                                                NaN
#
#                                           近三年主要績效(108~)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3147  一、研析國內外再生能源法規制度、協助再生能源補助及推廣工作，落實再生能源政策，推動國際交流工...
# 3148  一、冷凍空調領域_x000D_\n(一)推出自主化磁浮主軸總成，性能符合ISO-14839-...
# 3149  一、106年執行能源效率管理與提供節能技術服務，累計節能量達355.3千公秉油當量，相當於降...
# 3150  1.\t儲能系統標準暨檢測技術_x000D_\n\t106至107年期間協助電動車業者跨入...
# 3151  一、商業服務業溫室氣體減量示範輔導：輔導22家商業服務業連鎖加盟品牌(如：墊腳石、迪卡儂、涓...
#
#                                                  自我挑戰目標  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3147  一、原訂目標專利申請2件，挑戰目標專利申請3件。_x000D_\n二、原訂目標技術服務11家...
# 3148  一、原訂目標專利申請18件，挑戰目標專利申請24件。_x000D_\n二、原訂目標可移轉技術...
# 3149                 原訂目標節能目標為167千公秉油當量，挑戰目標為168千公秉油當量。
# 3150  1、原訂建置智慧家庭之HEMS檢測驗證中心場域1式，挑戰增加包含電動機車充電系統整合。_x0...
# 3151  1.\t透過本年度之策略性及前瞻創新推動作法，較前期相關計畫提高每投入一元之計畫經費所帶來的...
#
#                                         預期效益說明及效益評估方式規劃
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3147  (一)再生能源發展整合研究與推動計畫_x000D_\n(1)透過國內外再生能源法規及制度發展...
# 3148  甲、冷凍空調技術研發領域_x000D_\n(一)高效率空氣循環設備關鍵技術開發與應用計畫_x...
# 3149  (一)工業部門能源查核與節能輔導推廣計畫(4/4)_x000D_\n1.工業節能決策支援：執...
# 3150  一、預期效益：_x000D_\n1、建置國內首座符合國際標準之儲能系統測試驗證含特殊暨燃燒試...
# 3151  依據世界氣象組織(WMO) 的報告，2018年變暖趨勢仍在持續，全球平均氣溫為有記錄以來的第...
#
# [3152 rows x 60 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '系統編號', '計畫完整中文名稱', '年度', '部會', '主題重新分類', '主題1', '次主題1',
#        '主題2', '次主題2', '主題3', '次主題3', '主題4', '次主題4', '主題5', '次主題5', '主題6',
#        '次主題6', '主題7', '次主題7', '主題8', '次主題8', '主題9', '次主題9', '主題10', '次主題10',
#        '審議編號', '計畫類別', '舊額度來源', '新制額度類別', '戰略核心/重點政策/主軸/前瞻項目', '計畫屬性',
#        '預定執行機關', '中文關鍵詞', '英文關鍵詞', '前期綱要計畫系統編號', '前期綱要計畫備註說明', '政策編號1-編號',
#        '政策編號1-名稱', '政策編號1-措施', '政策編號2-編號', '政策編號2-名稱', '政策編號2-措施', '政策編號3-編號',
#        '政策編號3-名稱', '政策編號3-措施', '政策編號4-編號', '政策編號4-名稱', '政策編號4-措施', '政策編號5-編號',
#        '政策編號5-名稱', '政策編號5-措施', '政策其他理由', '本計畫在施政項目之定位及功能', '計畫重點描述', '最終效益',
#        '主要績效指標(~107)', '近三年主要績效(108~)', '自我挑戰目標', '預期效益說明及效益評估方式規劃'],
#       dtype='object')

# %%
df["主題重新分類"].value_counts()
# Out:
# 生技醫藥與精準醫療                    162
# 數位轉型與智慧政府                    121
# 環境監測與污染防治                     97
# 長照與社會福利                       82
# 網路通訊/4G/5G/5G+/6G             67
# 文化                            64
# 災害防救                          58
# 氣候變遷與減碳                       54
# 物聯網與虛擬實境                      52
# 數位內容                          48
# 防疫                            46
# 政策規劃與推動                       46
# 化工材料與循環經濟                     46
# 食品安全與食品科技                     41
# 傳統產業高值化                       41
# 能源                            37
# 晶片半導體                         37
# 自動駕駛                          33
# 校園人才培育                        32
# 中小（堅）企業輔導                     28
# AI、雲端、巨量資料                    26
# 多主題研究                         25
# 智慧製造                          24
# 設計                            23
# 數位學習                          20
# 運輸載具                          16
# 創新創業                          15
# 資安                            10
# 傳統產業高值化;運輸載具                  10
# 電商與物流                         10
# 產業人才培育                         9
# 專利與智財                          8
# 學術環境建構                         8
# 運輸載具;國防                        8
# 農業生技                           8
# 運動科技                           7
# 區塊鏈                            5
# 智慧農業                           3
# 農業                             3
# 晶片半導體;AI、雲端、巨量資料               3
# 長照與社會福利;網路通訊/4G/5G/5G+/6G      2
# 物聯網與虛擬實境;資安                    2
# 精準醫療與精準健康                      1
# 資安;網路通訊/4G/5G/5G+/6G           1
# Name: 主題重新分類, dtype: int64

# %%
import re
r = re.compile(r"\x28[^\x29]+\x29")
projlist = df[~df['主題1'].isnull()]['計畫完整中文名稱'].apply(lambda x: r.sub('', x))

# %%
csv = pd.read_csv("./revise_length_10.csv")

dictionary = {}
for i, n in enumerate(range(10), start=1):
    r = re.compile(r"\x28[^\x29]+\x29")
    
    ndf = df[~df[f'主題{i}'].isnull()]
    print(len(ndf['計畫完整中文名稱']))
    label_name = ndf[f'主題{i}'].tolist()[0]    
    proj = ndf['計畫完整中文名稱'].head(1).apply(lambda x: r.sub('', x)).tolist()[0]
    label = csv[csv['name'].astype(str).str.contains(proj)]['label'].tolist()[0]
    
    print(proj , label_name)        
    dictionary[label] = label_name
# Out:
# 110
# 奈米國家型科技計畫-奈米材料及製程技術發展綱要計畫 電池
# 26
# E化領域科技發展綱要計畫 智慧農業
# 151
# 建構國際級偏鄉數位資訊醫療照護網 5G
# 68
# 健康雲2.0 精準醫療與精準健康
# 174
# 科技應用與服務發展綱要計畫 創新創業
# 102
# 能源國家型科技計畫-教育部能源國家型科技人才培育計畫 再生能源
# 30
# 強化個資使用稽核及公務資料外洩防護計畫 資安人培
# 75
# 推動客家雲端服務暨建立基礎資料計畫 數位經濟
# 44
# 新興/再浮現傳染病監測技術開發與應用計畫 防疫科技
# 123
# 臺灣經典電影數位修復及加值利用計畫 文化

# %%
dictionary
# Out:
# {0: '電池',
#  1: '智慧農業',
#  2: '5G',
#  3: '精準醫療與精準健康',
#  4: '創新創業',
#  5: '再生能源',
#  6: '資安人培',
#  7: '數位經濟',
#  8: '防疫科技',
#  9: '文化'}

# %%
csv.label = csv.label.apply(lambda x: dictionary[x])

# %%
csv.to_csv("revise_length_10.csv", index=False)

# %%
ndf
# Out:
# 96        奈米國家型科技計畫-奈米材料及製程技術發展綱要計畫
# 100       能源國家型科技計畫-大型儲電元件與系統技術開發計畫
# 101          能源國家型科技計畫-能源產業技術發展綱要計畫
# 108              工研院創新前瞻技術研究綱要計畫書-
# 132                     智慧電動車產業推動計畫
#                    ...
# 3095                   綠能產業應用技術發展計畫
# 3099           綠能發配電智慧管理與效能提升技術發展計畫
# 3145              110年度「新及再生能源技術研發」
# 3147             110年度「再生能源開發與推廣計畫」
# 3150    儲能系統與智慧家庭能源管理系統標準檢測驗證能量建置計畫
# Name: 計畫完整中文名稱, Length: 110, dtype: object

# %%
df.columns
# Out:
# Index(['系統編號', '計畫完整中文名稱', '審議編號', '年度', '部會', '計畫類別', '舊額度來源', '新制額度類別',
#        '戰略核心/重點政策/主軸/前瞻項目', '計畫屬性', '預定執行機關', '中文關鍵詞', '英文關鍵詞', '前期綱要計畫系統編號',
#        '前期綱要計畫備註說明', '政策編號1-編號', '政策編號1-名稱', '政策編號1-措施', '政策編號2-編號',
#        '政策編號2-名稱', '政策編號2-措施', '政策編號3-編號', '政策編號3-名稱', '政策編號3-措施', '政策編號4-編號',
#        '政策編號4-名稱', '政策編號4-措施', '政策編號5-編號', '政策編號5-名稱', '政策編號5-措施', '政策其他理由',
#        '本計畫在施政項目之定位及功能', '計畫重點描述', '最終效益', '主要績效指標(~107)', '近三年主要績效(108~)',
#        '自我挑戰目標', '預期效益說明及效益評估方式規劃', '主題1', '次主題1', '主題2', '次主題2', '主題3',
#        '次主題3'],
#       dtype='object')

# %%
df.label.unique()
# Out:
# array([3, 1, 2, 9, 8, 7, 0, 5, 4, 6])

# %%
df[df['計畫完整中文名稱'].str.contains('電子光電產業科技發展綱要')][['計畫完整中文名稱', '中文關鍵詞']]['中文關鍵詞']
# Out:
# 927     矩陣式轉換器;熱電;智慧型功率模組;影像信號處理陣列;三維積體電路;三維堆疊組裝技術;室溫熱...
# 1347     交直流轉換器;熱電能源擷取;智慧型功率模組;影像導引系統;三維堆疊組裝技術;可捲曲有機發光二極體
# 1773    寬能隙晶圓;毫米波; 智慧型功率模組; 積體生物檢驗系統; 矽光子; 有機光波導; 超音波藥...
# 2149    印刷電路板;寬能隙晶圓;毫米波;陶瓷構裝材料;矽光子;有機光波導;數據中心;雷射光源;匯流排...
# Name: 中文關鍵詞, dtype: object

# %%
test = []
b = df[df['計畫完整中文名稱'].str.contains('電子光電產業科技發展綱要')][['計畫完整中文名稱', '中文關鍵詞']]['中文關鍵詞'].tolist()
print(len(b))
for i in b:    
    test += i.split(";")
test = list(set(test))
# Out:
# 4

# %%
intersection = set(test) & set(alla)
len(set(test)), len(set(alla)), len(intersection),
# Out:
# (56, 50, 48)

# %%
# Out:
# 積體生物檢驗系統
# YES
# 超音波藥物釋放系統
# YES

# %%
a = '軟性資訊顯示系統,矩陣式轉換器,三維積體電路,透明顯示器,積體生物檢驗系統,人工合成石墨片,陶瓷構裝材料,轉阻放大,照明產業,周邊監測安全防護雷達,岸際偵測雷達,眼球追蹤,有機光波導,三維超音波,熱膨脹精密量測,印刷電路板,矽光子,影像導引系統,智慧型功率模組,數據中心,互動式深度感測,即時資訊服務,生物半導體體外檢測系統,交直流轉換器,系統級封裝,試量產,非熱電型讀取積體電路晶片,影像信號處理陣列,軟性有機發光二極體,影像導引,室溫熱像晶片,寬能隙晶圓,軟性顯示器,面板級扇出型封裝技術,微波固態放大器,匯流排,毫米波,有機發光二極體照明,熱電,重分佈線路層,全域光學同調斷層掃瞄儀,超音波藥物釋放系統,計算儲存一體整合晶片,抗靜電電路之重分佈線路層,熱電能源擷取,三維堆疊組裝技術,雷射二極體驅動電路,可捲曲有機發光二極體,雷射光源,雲端運算'
alla = a.split(',')

# %%
alla
# Out:
# ['軟性資訊顯示系統',
#  '矩陣式轉換器',
#  '三維積體電路',
#  '透明顯示器',
#  '積體生物檢驗系統',
#  '人工合成石墨片',
#  '陶瓷構裝材料',
#  '轉阻放大',
#  '照明產業',
#  '周邊監測安全防護雷達',
#  '岸際偵測雷達',
#  '眼球追蹤',
#  '有機光波導',
#  '三維超音波',
#  '熱膨脹精密量測',
#  '印刷電路板',
#  '矽光子',
#  '影像導引系統',
#  '智慧型功率模組',
#  '數據中心',
#  '互動式深度感測',
#  '即時資訊服務',
#  '生物半導體體外檢測系統',
#  '交直流轉換器',
#  '系統級封裝',
#  '試量產',
#  '非熱電型讀取積體電路晶片',
#  '影像信號處理陣列',
#  '軟性有機發光二極體',
#  '影像導引',
#  '室溫熱像晶片',
#  '寬能隙晶圓',
#  '軟性顯示器',
#  '面板級扇出型封裝技術',
#  '微波固態放大器',
#  '匯流排',
#  '毫米波',
#  '有機發光二極體照明',
#  '熱電',
#  '重分佈線路層',
#  '全域光學同調斷層掃瞄儀',
#  '超音波藥物釋放系統',
#  '計算儲存一體整合晶片',
#  '抗靜電電路之重分佈線路層',
#  '熱電能源擷取',
#  '三維堆疊組裝技術',
#  '雷射二極體驅動電路',
#  '可捲曲有機發光二極體',
#  '雷射光源',
#  '雲端運算']

# %%
import pandas as pd

df = pd.read_csv("revise_length_20.csv")


df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#                label  num_label
# 202      時尚設計及國際商業服務          0
# 290             防疫科技          1
# 307        奈米晶片與元件工程          2
# 9          化工與機械工業製造          3
# 154            醫療及食安          4
# 353          水力與地質資源          5
# 362        智慧財產與專利檢索          6
# 111        地球科學與自然資源          7
# 77         人文及校園研究發展          8
# 27              創新創業          9
# 191        雲端、AI、大數據         10
# 51         資安人培與數位經濟         11
# 229        精準醫療與精準健康         12
# 382    跨領域多媒體與智慧技術整合         13
# 257          化學及環境污染         14
# 184               5G         15
# 344        健保長照與社會福利         16
# 0                 能源         17
# 275  航太科技及交通運輸(含自駕車)         18
# 168             智慧農業         19

# %%
df = pd.read_csv("revise_length_40.csv")

df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#      label  num_label
# 0        0          0
# 13       1          1
# 40       2          2
# 66       3          3
# 77       4          4
# 101      5          5
# 106      6          6
# 114      7          7
# 138      8          8
# 145      9          9
# 147     10         10
# 158     11         11
# 174     12         12
# 62      13         13
# 85      14         14
# 213     15         15
# 221     16         16
# 227     17         17
# 240     18         18
# 247     19         19
# 258     20         20
# 268     21         21
# 78      22         22
# 289     23         23
# 292     24         24
# 310     25         25
# 314     26         26
# 321     27         27
# 328     28         28
# 342     29         29
# 95      30         30
# 360     31         31
# 362     32         32
# 366     33         33
# 375     34         34
# 56      35         35
# 381     36         36
# 390     37         37
# 395     38         38
# 401     39         39

# %%
df = pd.read_csv("revise_length_30.csv")

df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#          label  num_label
# 359    資訊與資料風險          0
# 293    生物多樣性漁業          1
# 273    資訊產品及效能          2
# 70      智慧平台產品          3
# 264      地下水資源          4
# 370  放射性輻射及廢棄物          5
# 363       太空衛星          6
# 215     綠色材料環境          7
# 77      生物疫苗國家          8
# 115       藥物毒品          9
# 63      行動通訊網路         10
# 341       科技政策         11
# 325       氣象資訊         12
# 11      生技疾病生醫         13
# 94      智慧國際材料         14
# 196       科學領域         15
# 212       綠能能源         16
# 119     資料建築地震         17
# 338       資訊防護         18
# 178      奈米及輻射         19
# 377        農產品         20
# 317     電子商務物流         21
# 165     科技國際文化         22
# 391     智慧國際產業         23
# 0       機械產品工業         24
# 54      環境資料高齡         25
# 256       交通領域         26
# 39      軟體資訊網路         27
# 138      服務業商業         28
# 244     國際園區廠商         29
