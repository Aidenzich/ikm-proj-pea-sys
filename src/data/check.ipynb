# %%
import pandas as pd

df = pd.read_csv("revise_length_50.csv")

df
# df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#       year                           name  label  year_start  year_end  \
# 0      103                   國家生技研究園區開發計畫      3         103       106
# 1      103  創新轉譯農學研究：從系統生物學到農業生技產品關鍵技術之開發      1         103       107
# 2      103                科技會報科技政策發展研究與諮詢      2         103       104
# 3      103              臺灣經典電影數位修復及加值利用計畫      9         103       107
# 4      103                     數位媒體發展中心計畫      9         103       107
# ...    ...                            ...    ...         ...       ...
# 1501   110             110年度「再生能源開發與推廣計畫」      0         110       110
# 1502   110              110年度「節約能源技術研發計畫」      0         110       110
# 1503   110         110年度｢能源效率管理與節能技術推廣輔導」      0         110       110
# 1504   110    儲能系統與智慧家庭能源管理系統標準檢測驗證能量建置計畫      0         110       110
# 1505   110                  商業服務業節能低碳推動計畫      5         110       110
#
#      keyword  ner            tf_idf  \
# 0        NaN  NaN      \n\n\n\n\n\n
# 1        NaN  NaN              \n\n
# 2        NaN  NaN              \n\n
# 3        NaN  NaN  \n\n\n\n\n\n\n\n
# 4        NaN  NaN              \n\n
# ...      ...  ...               ...
# 1501     NaN  NaN               NaN
# 1502     NaN  NaN               NaN
# 1503     NaN  NaN               NaN
# 1504     NaN  NaN               NaN
# 1505     NaN  NaN               NaN
#
#                                             description  order  num_label
# 0      「國家生技研究園區」係以R&D為主的新一代國家型研究園區，主要以新藥研發為主。園區將基礎研...   2746          3
# 1     本計畫將系統生物學帶入轉譯農學研究，著重於農業生技產品關鍵技術之開發；並針對物種進行功能性探...   1497          1
# 2     一、研議國家科技發展政策審議及資源分配機制_x000D_\n二、籌辦行政院科技會報及重大科技...   1018          2
# 3     一、經典電影數位修復：精選典藏國、台語、紀錄片、新聞片重要影片分別進行數位修復、數位高階掃描...   1920          9
# 4     1、導入異業結盟及合作契機，開發影視多元、多樣、多用界面。_x000D_\n2、搭建跨部會合...   2083          9
# ...                                                 ...    ...        ...
# 1501  本項109年度「再生能源開發與推廣」計畫於110 年度進行下列9項分項計畫，相關之經費來源為...    299          0
# 1502  一、本計畫係配合綠能科技重點政策，於政府推動創能、節能、儲能及系統整合四大主軸中之「節能」與...    206          0
# 1503  1.能源查核與輔導：由自願性規範切入，視相關利害關係人因應能力，逐步演化制訂並執行強制性產品...    162          0
# 1504          本計畫係配合綠能政策目標時程，務須於113年底前完成大型儲能系統與電力智慧調...    339          0
# 1505  環保署現階段規劃住商部門2025年溫室氣體排放管制目標為較基準年 (2005年) 降低24%...    730          5
#
# [1506 rows x 11 columns]

# %%
df.label.unique()
# Out:
# array([3, 1, 2, 9, 8, 7, 0, 5, 4, 6])

# %%
import pandas as pd

df = pd.read_csv("revise_length_20.csv")


df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#                label  num_label
# 202      時尚設計及國際商業服務          0
# 290             防疫科技          1
# 307        奈米晶片與元件工程          2
# 9          化工與機械工業製造          3
# 154            醫療及食安          4
# 353          水力與地質資源          5
# 362        智慧財產與專利檢索          6
# 111        地球科學與自然資源          7
# 77         人文及校園研究發展          8
# 27              創新創業          9
# 191        雲端、AI、大數據         10
# 51         資安人培與數位經濟         11
# 229        精準醫療與精準健康         12
# 382    跨領域多媒體與智慧技術整合         13
# 257          化學及環境污染         14
# 184               5G         15
# 344        健保長照與社會福利         16
# 0                 能源         17
# 275  航太科技及交通運輸(含自駕車)         18
# 168             智慧農業         19

# %%
df = pd.read_csv("revise_length_40.csv")

df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#      label  num_label
# 0        0          0
# 13       1          1
# 40       2          2
# 66       3          3
# 77       4          4
# 101      5          5
# 106      6          6
# 114      7          7
# 138      8          8
# 145      9          9
# 147     10         10
# 158     11         11
# 174     12         12
# 62      13         13
# 85      14         14
# 213     15         15
# 221     16         16
# 227     17         17
# 240     18         18
# 247     19         19
# 258     20         20
# 268     21         21
# 78      22         22
# 289     23         23
# 292     24         24
# 310     25         25
# 314     26         26
# 321     27         27
# 328     28         28
# 342     29         29
# 95      30         30
# 360     31         31
# 362     32         32
# 366     33         33
# 375     34         34
# 56      35         35
# 381     36         36
# 390     37         37
# 395     38         38
# 401     39         39

# %%
df = pd.read_csv("revise_length_30.csv")

df[['label', 'num_label']].drop_duplicates().sort_values(by='num_label')
# Out:
#          label  num_label
# 359    資訊與資料風險          0
# 293    生物多樣性漁業          1
# 273    資訊產品及效能          2
# 70      智慧平台產品          3
# 264      地下水資源          4
# 370  放射性輻射及廢棄物          5
# 363       太空衛星          6
# 215     綠色材料環境          7
# 77      生物疫苗國家          8
# 115       藥物毒品          9
# 63      行動通訊網路         10
# 341       科技政策         11
# 325       氣象資訊         12
# 11      生技疾病生醫         13
# 94      智慧國際材料         14
# 196       科學領域         15
# 212       綠能能源         16
# 119     資料建築地震         17
# 338       資訊防護         18
# 178      奈米及輻射         19
# 377        農產品         20
# 317     電子商務物流         21
# 165     科技國際文化         22
# 391     智慧國際產業         23
# 0       機械產品工業         24
# 54      環境資料高齡         25
# 256       交通領域         26
# 39      軟體資訊網路         27
# 138      服務業商業         28
# 244     國際園區廠商         29
